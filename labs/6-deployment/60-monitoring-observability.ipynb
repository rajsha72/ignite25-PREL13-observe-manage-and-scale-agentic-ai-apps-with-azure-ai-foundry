# %% [markdown]
# ## Monitoring in Foundry Portal
#
# - Access the Foundry portal to view real-time metrics and health of your deployed agents.
# - Use built-in dashboards for quick insights.
#
# ![](../assets/05-tracing-resourceusage.png)

# %% [markdown]
# ## Application Insights Dashboards
#
# - Set up Application Insights to collect telemetry data from your application.
# - Create custom dashboards to visualize performance, failures, and usage.
#
# ![](../assets/05-tracing-applicationinsights.png)

# %% [markdown]
# ## Tracing with OpenTelemetry
#
# - Implement OpenTelemetry in your application for distributed tracing.
# - Export traces to Azure Monitor or other observability platforms.
#
# ![](../assets/05-tracing-single-trace.png)
